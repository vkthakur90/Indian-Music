# %% [markdown]
# <a href="https://colab.research.google.com/github/vkthakur90/Indian-Music/blob/main/Stable_Diffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q --upgrade keras-cv

# %%
import time
import keras_cv
from tensorflow import keras
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend

# %%
model = keras_cv.models.StableDiffusion(img_width=512, img_height=512, jit_compile = True)
# Out:
# By using this model checkpoint, you acknowledge that its usage is subject to the terms of the CreativeML Open RAIL-M license at https://raw.githubusercontent.com/CompVis/stable-diffusion/main/LICENSE

# %%
images = model.text_to_image(
    prompt = """
        Photograph of Dog
    """,
    num_steps = 50,
    unconditional_guidance_scale = 7
)

img = keras.utils.array_to_img(images[0])
# Out:
# ...
# 198180272/198180272 [==============================] - 1s 0us/step

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
